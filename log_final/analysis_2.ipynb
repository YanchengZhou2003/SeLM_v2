# %%
# =========================
# Step 0: 依赖
# =========================
import os
import re
from typing import Dict, List, Any
import pandas as pd
import matplotlib.pyplot as plt

# =========================
# Step 1: 文件名生成层
# =========================
def make_log_filename(ratio_cos: str, temperature: int, prefix: str = "ratio_cos") -> str:
    """
    根据 ratio_cos (字符串) 和 temperature (整数) 生成文件名
    """
    return f"{prefix}{ratio_cos}_temp{temperature}.log"


def make_log_filenames(ratio_list, temp_list, prefix="ratio_cos") -> List[str]:
    """
    批量生成文件名
    ratio_list: ["0.999", "0.99", ...]
    temp_list: [1, 2, 4, 8, 16, 32]
    """
    return [make_log_filename(ratio, temp, prefix) for ratio in ratio_list for temp in temp_list]


def list_existing_logs(log_dir: str, candidates: List[str]) -> List[str]:
    return [os.path.join(log_dir, f) for f in candidates if os.path.exists(os.path.join(log_dir, f))]

# =========================
# Step 2: 解析引擎层（单文件）
# =========================
FNAME_RE = re.compile(r"^ratio_cos(?P<cos>[0-9.]+)_temp(?P<temp>\d+)\.log$")



FLOAT = r"[-+]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][-+]?\d+)?"
TRAIN_SUMMARY_RE = re.compile(r"^epoch\s+(\d+)\s+summary:\s+(.*)$")
TRAIN_KV_RE      = re.compile(rf"(\w+_loss)\s*:\s*({FLOAT})")
VALID_SUMMARY_RE = re.compile(r"^epoch\s+(\d+)\s+summary:\s+.*(valid_cos_loss)\s*:\s*(" + FLOAT + r")")
VALID_LINE_RE    = re.compile(r"^valid loss:\s*(" + FLOAT + r")\b")

def parse_filename_meta(filename: str) -> Dict[str, Any]:
    m = FNAME_RE.match(filename)
    if not m:
        return {"file": filename, "ratio_cos": None, "temperature": None}
    return {
        "file": filename,
        "ratio_cos": float(m.group("cos")),
        "temperature": int(m.group("temp"))
    }


def parse_log_file(filepath: str) -> Dict[str, Any]:
    meta = parse_filename_meta(os.path.basename(filepath))
    series: Dict[str, List[float]] = {
        "train_cos_loss": [], "train_cro_loss": [], "train_tot_loss": [], "vocab_cos_loss": [],
        "valid_cos_loss": [], "valid_loss": []
    }
    epochs_train: List[int] = []
    epochs_valid: List[int] = []
    last_epoch_seen: int | None = None

    with open(filepath, "r") as f:
        for line in f:
            line = line.strip()

            mt = TRAIN_SUMMARY_RE.match(line)
            if mt:
                ep = int(mt.group(1))
                last_epoch_seen = ep
                kv_part = mt.group(2)
                for k, v in TRAIN_KV_RE.findall(kv_part):
                    if k in series:
                        series[k].append(float(v))
                epochs_train.append(ep)
                continue

            mv = VALID_SUMMARY_RE.match(line)
            if mv:
                ep_v = int(mv.group(1))
                last_epoch_seen = ep_v
                val_cos = float(mv.group(3))
                series["valid_cos_loss"].append(val_cos)
                epochs_valid.append(ep_v)
                continue

            ml = VALID_LINE_RE.match(line)
            if ml:
                vloss = float(ml.group(1))
                series["valid_loss"].append(vloss)
                if last_epoch_seen is not None and (not epochs_valid or epochs_valid[-1] != last_epoch_seen):
                    epochs_valid.append(last_epoch_seen)

    return {"meta": meta, "series": series, "epochs_train": epochs_train, "epochs_valid": epochs_valid}

# =========================
# Step 3: 批量收集层
# =========================
def parse_multiple_logs(filepaths: List[str]) -> List[Dict[str, Any]]:
    runs = []
    for p in filepaths:
        try:
            runs.append(parse_log_file(p))
            print(f"Parsed {p}")
        except Exception as e:
            runs.append({"meta": {"file": os.path.basename(p), "h": None, "tp": None},
                         "series": {}, "error": str(e)})
    return runs

# =========================
# Step 4: 聚合与特征派生层
# =========================
def build_final_metrics_table(runs: List[Dict[str, Any]]) -> pd.DataFrame:
    rows: List[Dict[str, Any]] = []
    for r in runs:
        meta = r.get("meta", {})
        ser  = r.get("series", {})

        def last_or_nan(lst):
            return lst[-1] if lst else float("nan")

        rows.append({
            "file": meta.get("file"),
            "ratio_cos": meta.get("ratio_cos"),
            "temperature": meta.get("temperature"),
            "final_train_cos_loss": last_or_nan(ser.get("train_cos_loss", [])),
            "final_train_cro_loss": last_or_nan(ser.get("train_cro_loss", [])),
            "final_train_tot_loss": last_or_nan(ser.get("train_tot_loss", [])),
            "final_vocab_cos_loss": last_or_nan(ser.get("vocab_cos_loss", [])),
            "final_valid_cos_loss": last_or_nan(ser.get("valid_cos_loss", [])),
            "final_valid_loss": last_or_nan(ser.get("valid_loss", [])),
        })
    return pd.DataFrame(rows)




# =========================
# Step 5: 可视化层
# =========================
def plot_valid_loss_vs_ratio_cos(df_final: pd.DataFrame):
    """
    绘制 final_valid_loss vs ratio_cos
    - 横轴: ratio_cos
    - 纵轴: final_valid_loss
    - 不同 temperature: 不同曲线
    """
    if df_final.empty:
        print("No data to plot.")
        return

    fig, ax = plt.subplots(figsize=(7, 5))

    for temp, grp in df_final.groupby("temperature"):
        g = grp.dropna(subset=["final_valid_loss"]).sort_values("ratio_cos")
        if g.empty:
            continue
        ax.plot(g["ratio_cos"], g["final_valid_loss"], marker="o", label=f"temp={temp}")

    ax.set_xlabel("ratio_cos")
    ax.set_ylabel("final valid_loss")
    ax.set_title("final valid_loss vs ratio_cos (grouped by temperature)")
    ax.grid(True, ls="--")
    ax.legend()
    plt.tight_layout()
    plt.show()


def plot_avg_train_cro_loss_vs_ratio_cos(runs: List[Dict[str, Any]]):
    """
    从 runs 直接计算并绘制：
    - 平均 train_cro_loss (epoch 70~90) vs ratio_cos
    - 横轴: ratio_cos
    - 纵轴: avg train_cro_loss (epoch 70~90)
    - 不同 temperature: 不同曲线
    """
    records = []
    for r in runs:
        meta = r.get("meta", {})
        ser  = r.get("series", {})
        ratio, temp = meta.get("ratio_cos"), meta.get("temperature")
        losses = ser.get("train_cro_loss", [])

        if len(losses) > 70:
            end = min(91, len(losses))
            sub = losses[70:end]
            avg_loss = sum(sub) / len(sub) if sub else float("nan")
        else:
            avg_loss = float("nan")

        records.append({"ratio_cos": ratio, "temperature": temp, "avg_train_cro_loss_70_90": avg_loss})

    df_plot = pd.DataFrame(records)

    fig, ax = plt.subplots(figsize=(7, 5))
    for temp, grp in df_plot.groupby("temperature"):
        g = grp.dropna(subset=["avg_train_cro_loss_70_90"]).sort_values("ratio_cos")
        if g.empty:
            continue
        ax.plot(g["ratio_cos"], g["avg_train_cro_loss_70_90"], marker="o", label=f"temp={temp}")

    ax.set_xlabel("ratio_cos")
    ax.set_ylabel("avg train_cro_loss (epoch 70–90)")
    ax.set_title("Average train_cro_loss (70–90) vs ratio_cos (grouped by temperature)")
    ax.grid(True, ls="--")
    ax.legend()
    plt.tight_layout()
    plt.show()



# =========================
# Step 6: 示例（按需启用）
# =========================
log_dir = "."
ratio_list = ["0.999", "0.99", "0.95", "0.90", "0.75", "0.50", "0.25"]
temp_list  = [1, 2, 4, 8, 16, 32]

candidates = make_log_filenames(ratio_list, temp_list)
print("候选文件:", candidates)
filepaths  = list_existing_logs(log_dir, candidates)
runs       = parse_multiple_logs(filepaths)

df_final = build_final_metrics_table(runs)
display(df_final.sort_values(["ratio_cos", "temperature"]))

plot_valid_loss_vs_ratio_cos(df_final)
plot_avg_train_cro_loss_vs_ratio_cos(runs)
# Out:
# 候选文件: ['ratio_cos0.999_temp1.log', 'ratio_cos0.999_temp2.log', 'ratio_cos0.999_temp4.log', 'ratio_cos0.999_temp8.log', 'ratio_cos0.999_temp16.log', 'ratio_cos0.999_temp32.log', 'ratio_cos0.99_temp1.log', 'ratio_cos0.99_temp2.log', 'ratio_cos0.99_temp4.log', 'ratio_cos0.99_temp8.log', 'ratio_cos0.99_temp16.log', 'ratio_cos0.99_temp32.log', 'ratio_cos0.95_temp1.log', 'ratio_cos0.95_temp2.log', 'ratio_cos0.95_temp4.log', 'ratio_cos0.95_temp8.log', 'ratio_cos0.95_temp16.log', 'ratio_cos0.95_temp32.log', 'ratio_cos0.90_temp1.log', 'ratio_cos0.90_temp2.log', 'ratio_cos0.90_temp4.log', 'ratio_cos0.90_temp8.log', 'ratio_cos0.90_temp16.log', 'ratio_cos0.90_temp32.log', 'ratio_cos0.75_temp1.log', 'ratio_cos0.75_temp2.log', 'ratio_cos0.75_temp4.log', 'ratio_cos0.75_temp8.log', 'ratio_cos0.75_temp16.log', 'ratio_cos0.75_temp32.log', 'ratio_cos0.50_temp1.log', 'ratio_cos0.50_temp2.log', 'ratio_cos0.50_temp4.log', 'ratio_cos0.50_temp8.log', 'ratio_cos0.50_temp16.log', 'ratio_cos0.50_temp32.log', 'ratio_cos0.25_temp1.log', 'ratio_cos0.25_temp2.log', 'ratio_cos0.25_temp4.log', 'ratio_cos0.25_temp8.log', 'ratio_cos0.25_temp16.log', 'ratio_cos0.25_temp32.log']
# Parsed ./ratio_cos0.999_temp1.log
# Parsed ./ratio_cos0.999_temp2.log
# Parsed ./ratio_cos0.999_temp4.log
# Parsed ./ratio_cos0.999_temp8.log
# Parsed ./ratio_cos0.999_temp16.log
# Parsed ./ratio_cos0.999_temp32.log
# Parsed ./ratio_cos0.99_temp1.log
# Parsed ./ratio_cos0.99_temp2.log
# Parsed ./ratio_cos0.99_temp4.log
# Parsed ./ratio_cos0.99_temp8.log
# Parsed ./ratio_cos0.99_temp16.log
# Parsed ./ratio_cos0.99_temp32.log
# Parsed ./ratio_cos0.95_temp1.log
# Parsed ./ratio_cos0.95_temp2.log
# Parsed ./ratio_cos0.95_temp4.log
# Parsed ./ratio_cos0.95_temp8.log
# Parsed ./ratio_cos0.95_temp16.log
# Parsed ./ratio_cos0.95_temp32.log
# Parsed ./ratio_cos0.90_temp1.log
# Parsed ./ratio_cos0.90_temp2.log
# Parsed ./ratio_cos0.90_temp4.log
# Parsed ./ratio_cos0.90_temp8.log
# Parsed ./ratio_cos0.90_temp16.log
# Parsed ./ratio_cos0.90_temp32.log
# Parsed ./ratio_cos0.75_temp1.log
# Parsed ./ratio_cos0.75_temp2.log
# Parsed ./ratio_cos0.75_temp4.log
# Parsed ./ratio_cos0.75_temp8.log
# Parsed ./ratio_cos0.75_temp16.log
# Parsed ./ratio_cos0.75_temp32.log
# Parsed ./ratio_cos0.50_temp1.log
# Parsed ./ratio_cos0.50_temp2.log
# Parsed ./ratio_cos0.50_temp4.log
# Parsed ./ratio_cos0.50_temp8.log
# Parsed ./ratio_cos0.50_temp16.log
# Parsed ./ratio_cos0.50_temp32.log
# Parsed ./ratio_cos0.25_temp1.log
# Parsed ./ratio_cos0.25_temp2.log
# Parsed ./ratio_cos0.25_temp4.log
# Parsed ./ratio_cos0.25_temp8.log
# Parsed ./ratio_cos0.25_temp16.log
# Parsed ./ratio_cos0.25_temp32.log
#                          file  ratio_cos  temperature  final_train_cos_loss  \
# 36    ratio_cos0.25_temp1.log      0.250            1              0.051466
# 37    ratio_cos0.25_temp2.log      0.250            2              0.051466
# 38    ratio_cos0.25_temp4.log      0.250            4              0.051466
# 39    ratio_cos0.25_temp8.log      0.250            8              0.051466
# 40   ratio_cos0.25_temp16.log      0.250           16              0.051466
# 41   ratio_cos0.25_temp32.log      0.250           32              0.054103
# 30    ratio_cos0.50_temp1.log      0.500            1              0.050058
# 31    ratio_cos0.50_temp2.log      0.500            2              0.050058
# 32    ratio_cos0.50_temp4.log      0.500            4              0.050058
# 33    ratio_cos0.50_temp8.log      0.500            8              0.050058
# 34   ratio_cos0.50_temp16.log      0.500           16              0.050058
# 35   ratio_cos0.50_temp32.log      0.500           32              0.050058
# 24    ratio_cos0.75_temp1.log      0.750            1              0.046205
# 25    ratio_cos0.75_temp2.log      0.750            2              0.046205
# 26    ratio_cos0.75_temp4.log      0.750            4              0.046205
# 27    ratio_cos0.75_temp8.log      0.750            8              0.046205
# 28   ratio_cos0.75_temp16.log      0.750           16              0.046205
# 29   ratio_cos0.75_temp32.log      0.750           32              0.046205
# 18    ratio_cos0.90_temp1.log      0.900            1              0.044688
# 19    ratio_cos0.90_temp2.log      0.900            2              0.044688
# 20    ratio_cos0.90_temp4.log      0.900            4              0.044688
# 21    ratio_cos0.90_temp8.log      0.900            8              0.044688
# 22   ratio_cos0.90_temp16.log      0.900           16              0.044688
# 23   ratio_cos0.90_temp32.log      0.900           32              0.044688
# 12    ratio_cos0.95_temp1.log      0.950            1              0.040529
# 13    ratio_cos0.95_temp2.log      0.950            2              0.040529
# 14    ratio_cos0.95_temp4.log      0.950            4              0.040529
# 15    ratio_cos0.95_temp8.log      0.950            8              0.040529
# 16   ratio_cos0.95_temp16.log      0.950           16              0.040529
# 17   ratio_cos0.95_temp32.log      0.950           32              0.040529
# 6     ratio_cos0.99_temp1.log      0.990            1              0.025235
# 7     ratio_cos0.99_temp2.log      0.990            2              0.025235
# 8     ratio_cos0.99_temp4.log      0.990            4              0.025235
# 9     ratio_cos0.99_temp8.log      0.990            8              0.025235
# 10   ratio_cos0.99_temp16.log      0.990           16              0.025235
# 11   ratio_cos0.99_temp32.log      0.990           32              0.025235
# 0    ratio_cos0.999_temp1.log      0.999            1              0.021977
# 1    ratio_cos0.999_temp2.log      0.999            2              0.021977
# 2    ratio_cos0.999_temp4.log      0.999            4              0.021977
# 3    ratio_cos0.999_temp8.log      0.999            8              0.021977
# 4   ratio_cos0.999_temp16.log      0.999           16              0.021977
# 5   ratio_cos0.999_temp32.log      0.999           32              0.021977
#
#     final_train_cro_loss  final_train_tot_loss  final_vocab_cos_loss  \
# 36                0.1011                0.0887              0.010573
# 37                0.1011                0.0887              0.010573
# 38                0.1011                0.0887              0.010573
# 39                0.1011                0.0887              0.010573
# 40                0.1011                0.0887              0.010573
# 41                0.0980                0.0870              0.010569
# 30                0.2066                0.1283              0.010080
# 31                0.2066                0.1283              0.010080
# 32                0.2066                0.1283              0.010080
# 33                0.2066                0.1283              0.010080
# 34                0.2066                0.1283              0.010080
# 35                0.2066                0.1283              0.010080
# 24                0.2153                0.0885              0.010080
# 25                0.2153                0.0885              0.010080
# 26                0.2153                0.0885              0.010080
# 27                0.2153                0.0885              0.010080
# 28                0.2153                0.0885              0.010080
# 29                0.2153                0.0885              0.010080
# 18                0.2305                0.0633              0.010080
# 19                0.2305                0.0633              0.010080
# 20                0.2305                0.0633              0.010080
# 21                0.2305                0.0633              0.010080
# 22                0.2305                0.0633              0.010080
# 23                0.2305                0.0633              0.010080
# 12                0.2554                0.0513              0.010080
# 13                0.2554                0.0513              0.010080
# 14                0.2554                0.0513              0.010080
# 15                0.2554                0.0513              0.010080
# 16                0.2554                0.0513              0.010080
# 17                0.2554                0.0513              0.010080
# 6                 0.3822                0.0288              0.010080
# 7                 0.3822                0.0288              0.010080
# 8                 0.3822                0.0288              0.010080
# 9                 0.3822                0.0288              0.010080
# 10                0.3822                0.0288              0.010080
# 11                0.3822                0.0288              0.010080
# 0                 3.6711                0.0256              0.010080
# 1                 3.6711                0.0256              0.010080
# 2                 3.6711                0.0256              0.010080
# 3                 3.6711                0.0256              0.010080
# 4                 3.6711                0.0256              0.010080
# 5                 3.6711                0.0256              0.010080
#
#     final_valid_cos_loss  final_valid_loss
# 36                   NaN               NaN
# 37                   NaN               NaN
# 38                   NaN               NaN
# 39                   NaN               NaN
# 40                   NaN               NaN
# 41                   NaN               NaN
# 30              0.045843            2.8587
# 31              0.045843            2.8587
# 32              0.045843            2.8587
# 33              0.045843            2.8587
# 34              0.045843            2.8587
# 35              0.045843            2.8587
# 24              0.044267            2.8259
# 25              0.044267            2.8259
# 26              0.044267            2.8259
# 27              0.044267            2.8259
# 28              0.044267            2.8259
# 29              0.044267            2.8259
# 18              0.043122            2.6870
# 19              0.043122            2.6870
# 20              0.043122            2.6870
# 21              0.043122            2.6870
# 22              0.043122            2.6870
# 23              0.043122            2.6870
# 12              0.040216            2.5629
# 13              0.040216            2.5629
# 14              0.040216            2.5629
# 15              0.040216            2.5629
# 16              0.040216            2.5629
# 17              0.040216            2.5629
# 6               0.024978            2.4033
# 7               0.024978            2.4033
# 8               0.024978            2.4033
# 9               0.024978            2.4033
# 10              0.024978            2.4033
# 11              0.024978            2.4033
# 0               0.021885            3.9825
# 1               0.021885            3.9825
# 2               0.021885            3.9825
# 3               0.021885            3.9825
# 4               0.021885            3.9825
# 5               0.021885            3.9825
